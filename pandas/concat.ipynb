# %%
import pandas as pd

india_weather =pd.DataFrame({
    "city":["mumbai","delhi","banalore"],
    "temperature":[32,44,30],
    "heumidity":[80,60,78]
})
india_weather
# Out:
#        city  temperature  heumidity
# 0    mumbai           32         80
# 1     delhi           44         60
# 2  banalore           30         78

# %%
us_weather=pd.DataFrame({
    "city":["new york","chicago","orlando"],
    "temperature":[21,14,35],
    "heumidity":[68,65,75]
})
us_weather
# Out:
#        city  temperature  heumidity
# 0  new york           21         68
# 1   chicago           14         65
# 2   orlando           35         75

# %%
df =pd.concat([india_weather,us_weather])
df
# Out:
#        city  temperature  heumidity
# 0    mumbai           32         80
# 1     delhi           44         60
# 2  banalore           30         78
# 0  new york           21         68
# 1   chicago           14         65
# 2   orlando           35         75

# %%
df =pd.concat([india_weather,us_weather], ignore_index=True)
df
# Out:
#        city  temperature  heumidity
# 0    mumbai           32         80
# 1     delhi           44         60
# 2  banalore           30         78
# 3  new york           21         68
# 4   chicago           14         65
# 5   orlando           35         75

# %%
df =pd.concat([india_weather,us_weather], keys=["india","us"])
df
# Out:
#              city  temperature  heumidity
# india 0    mumbai           32         80
#       1     delhi           44         60
#       2  banalore           30         78
# us    0  new york           21         68
#       1   chicago           14         65
#       2   orlando           35         75

# %%
df.loc["india"]
# Out:
#        city  temperature  heumidity
# 0    mumbai           32         80
# 1     delhi           44         60
# 2  banalore           30         78

# %%
df.loc["us"]
# Out:
#        city  temperature  heumidity
# 0  new york           21         68
# 1   chicago           14         65
# 2   orlando           35         75

# %%
temp_df =pd.DataFrame({
    "city":["mumbai","delhi","banalore"],
    "temperature":[32,44,30],
}, index=[0,1,2])
temp_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           44
# 2  banalore           30

# %%
windspeed_df = pd.DataFrame({
    "city":["delhi","mumbai","banalore"],
    "windspeed":[67,56,9],
},index=[1,0,2])
windspeed_df
# Out:
#        city  windspeed
# 1     delhi         67
# 0    mumbai         56
# 2  banalore          9

# %%
df =pd.concat([temp_df,windspeed_df], axis=1)
df
# Out:
#        city  temperature      city  windspeed
# 0    mumbai           32    mumbai         56
# 1     delhi           44     delhi         67
# 2  banalore           30  banalore          9

# %%
temp_df
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           44
# 2  banalore           30

# %%
s = pd.Series(["Humid","Dry","Rain"], name="event")
s
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temp_df, s],axis=1)
df
# Out:
#        city  temperature  event
# 0    mumbai           32  Humid
# 1     delhi           44    Dry
# 2  banalore           30   Rain
